# %% [markdown]
# 1.
# Flask is a web application framework written in Python.
#
# Advantages :
# It is a lightweight framework that offers hassle-free development.
# Provide flexibility to the developer to experiment with their modules or architecture.
# It is suitable for small projects.
# Offers a built-in development server and fast debugger.
# Easily scalable for the applications.
# Support for secure cookies.

# %% [markdown]
# 2.
#
# from flask import Flask
# from flask import request
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "<h 1> Hello World !! </h 1>"
#
#
# @app.route("/tt")
# def tst():
#     data = request.args.get('d')
#     return "You are searching,{}".format(data)
#
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
#
# ![image.png](attachment:01e9554b-f841-444b-928e-3cac395e6663.png)

# %% [markdown]
# 3.
# App routing is the technique used to map the specific URL with the associated function intended to perform some task.
#
# help users remember application URLs & helpful to access the desired page directly without navigating from the home page.

# %% [markdown]
# 4.
# from flask import Flask
# from flask import request
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return """Company Name: ABC Corporation \n
#               Location: India \n
#               Contact Detail: 999-999-9999"""
#
# @app.route("/welcome")
# def welcome():
#     return "Welcome to ABC Corporation"
#
# @app.route("/tt")
# def tst():
#     data = request.args.get('d')
#     return "You are searching,{}".format(data)
#
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
#
#
#
# ![image.png](attachment:89f3d02a-fe95-4e57-bc36-16188215a974.png)
# ![image.png](attachment:e4bc324c-7044-426d-b99e-a0c23d1f419b.png)

# %% [markdown]
# 5.
# Flask url_for is defined as a function that enables developers to build and generate URLs on a Flask application.
#
# The url_for() function is very useful for dynamically building a URL for a specific function. The function accepts the name of a function as first argument, and one or more keyword arguments, each corresponding to the variable part of URL.
